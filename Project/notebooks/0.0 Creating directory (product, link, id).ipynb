# %% [markdown]
# ### Extracting product id from the weblinks

# %% [markdown]
# Necessary step to act as reference for web scraping for reviews

# %%
#Import necessary libraries
import json 
import re
import os
import pandas as pd

# %%
with open('../data/raw_data/initial.json', 'r') as file:
    raw_data= json.load(file)
df=pd.DataFrame.from_dict(raw_data)

# %%
df['product_id']=df.weblink.str.partition(sep='grid:')[2]

# %%
df.columns
# Out:
# Index(['index', 'brand', 'name', 'about the product', 'weblink',
#        'sub_category', 'main_category', 'num_likes', 'img_link', 'price',
#        'size', 'ingredients', 'rating', 'num_reviews', 'highlights',
#        'product_name', 'sensitive', 'combination', 'oily', 'normal', 'dry',
#        'clean', 'cruelty-free', 'vegan', 'skin_concerns', 'excl_ingr',
#        'best for', 'acids', 'award', 'size_oz', 'size_ml', 'size_g',
#        'pricepervol', 'highlighted_ingr', 'clinical_results', 'formulation',
#        'formulation_type', 'richness', 'product_type', 'product_id'],
#       dtype='object')

# %%
df.drop(columns=['index'], inplace=True)

# %%
df_links_id=df[['product_name', 'weblink', 'product_id', 'num_reviews']].copy()

# %%
with open('../data/processed_data/combined_data.json', 'r') as file:
    raw_data= json.load(file)
selected=pd.DataFrame.from_dict(raw_data)

# %%
selected_df= pd.merge(selected, df_links_id, on='product_name', how='left')

# %%
datapath_data = os.path.join('../data/raw_data', 'pre_selection.json')
if not os.path.exists(datapath_data):
    selected_df.to_json(datapath_data)

# %%
datapath_data = os.path.join('../data/raw_data', 'data_links_id.json')
if not os.path.exists(datapath_data):
    df_links_id.to_json(datapath_data)

# %% [markdown]
# ______________________________________________________________________

# %% [markdown]
# # Creating full list of product_ids scraped

# %%
#Storing each raw json file in a dataframe 
with open('../data/raw_data/cleansers_full.json', 'r') as file:
    raw_data= json.load(file)
cleansers_raw=pd.DataFrame.from_dict(raw_data)

with open('../data/raw_data/eye_products.json', 'r') as file:
    raw_data= json.load(file)
eyeproducts_raw=pd.DataFrame.from_dict(raw_data)

with open('../data/raw_data/moisturizers_full.json', 'r') as file:
    raw_data= json.load(file)
moisturizers_raw=pd.DataFrame.from_dict(raw_data)

with open('../data/raw_data/treatments_full.json', 'r') as file:
    raw_data= json.load(file)
treatments_raw=pd.DataFrame.from_dict(raw_data)

# %%
full_df= pd.concat([cleansers_raw, eyeproducts_raw, moisturizers_raw, treatments_raw])

# %%
full_df['product_id']=full_df.weblink.str.partition(sep='grid:')[2]

# %%
#Also need to fix number of reviews 
full_df.drop(full_df[full_df['num_reviews'].isnull()].index, inplace=True)

# %%
#Cleaning num_reviews column
full_df.loc[full_df.num_reviews.str.endswith('K'), 'num_reviews']=full_df.loc[full_df.num_reviews.str.endswith('K'), 'num_reviews'].str.strip('K').astype('float64')*1000
full_df['num_reviews']=full_df['num_reviews'].astype('int64')

# %%
full_df.reset_index(inplace=True)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   level_0            1825 non-null   int64
#  1   index              1825 non-null   int64
#  2   brand              1825 non-null   object
#  3   name               1825 non-null   object
#  4   about the product  1825 non-null   object
#  5   weblink            1825 non-null   object
#  6   sub_category       1825 non-null   object
#  7   main_category      1825 non-null   object
#  8   num_likes          1825 non-null   object
#  9   img_link           1825 non-null   object
#  10  price              1809 non-null   object
#  11  size               1599 non-null   object
#  12  ingredients        1825 non-null   object
#  13  rating             1825 non-null   object
#  14  num_reviews        1825 non-null   int64
#  15  highlights         1825 non-null   object
#  16  product_id         1825 non-null   object
# dtypes: int64(3), object(14)
# memory usage: 242.5+ KB

# %%
datapath3 = os.path.join('../data/raw_data', 'preprocessed_full.json')
if not os.path.exists(datapath3):
    full_df.to_json(datapath3)

# %%
full_df
# Out:
#       level_0  index                brand  \
# 0           0      0          Glow Recipe
# 1           1      1       Drunk Elephant
# 2           2      2               Tatcha
# 3           3      3                 goop
# 4           4      4              Lancôme
# ...       ...    ...                  ...
# 1820     1847    573              Farmacy
# 1821     1848    574      Kate Somerville
# 1822     1849    575         Estée Lauder
# 1823     1850    576  Dr. Brandt Skincare
# 1824     1851    577         IT Cosmetics
#
#                                                    name  \
# 0             Watermelon Glow PHA +BHA Pore-Tight Toner
# 1                Slaai™  Makeup-Melting Butter Cleanser
# 2                   Pure One Step Camellia Oil Cleanser
# 3            GOOPGLOW Microderm Instant Glow Exfoliator
# 4             Bi-Facil Double-Action Eye Makeup Remover
# ...                                                 ...
# 1820  Very Cherry Bright 15% Clean Vitamin C Serum w...
# 1821                                  Breakout Fighters
# 1822    Advanced Night Repair Intense Reset Concentrate
# 1823  Dark Spots No More® Triple Acid Spot Minimizin...
# 1824                     Bye Bye Lines Anti-Aging Serum
#
#                                       about the product  \
# 0     [What it is: , A bestselling gentle, PHA- and ...
# 1     [What it is:  , An innovative cleansing balm t...
# 2     [Which skin type is it good for?, ✔ Normal, ✔ ...
# 3     [What it is: ,  A clinically tested, dual-acti...
# 4     [What it is:  , An award-winning makeup remove...
# ...                                                 ...
# 1820  [What it is:,  A potent 15 percent vitamin C s...
# 1821  [Which skin type is it good for?, ✔ Normal, ✔ ...
# 1822  [What it is: ,  An overnight treatment that so...
# 1823  [What it is: ,  A targeted, daily concentrate ...
# 1824  [Which skin type is it good for?, ✔ Normal, ✔ ...
#
#                                                 weblink  \
# 0     https://www.sephora.com/product/cleansing-exfo...
# 1     https://www.sephora.com/product/cleansing-exfo...
# 2     https://www.sephora.com/product/cleansing-exfo...
# 3     https://www.sephora.com/product/cleansing-exfo...
# 4     https://www.sephora.com/product/cleansing-exfo...
# ...                                                 ...
# 1820  https://www.sephora.com/product/advanced-night...
# 1821  https://www.sephora.com/product/advanced-night...
# 1822  https://www.sephora.com/product/advanced-night...
# 1823  https://www.sephora.com/product/bye-bye-lines-...
# 1824  https://www.sephora.com/product/bye-bye-lines-...
#
#                sub_category main_category num_likes  \
# 0                    Toners     cleansers    125.1K
# 1     Face Wash & Cleansers     cleansers     66.6K
# 2     Face Wash & Cleansers     cleansers    107.6K
# 3               Exfoliators     cleansers     12.9K
# 4           Makeup Removers     cleansers     58.7K
# ...                     ...           ...       ...
# 1820            Face Serums    treatments       22K
# 1821      Value & Gift Sets    treatments     14.7K
# 1822            Face Serums    treatments      8.7K
# 1823            Face Serums    treatments      8.5K
# 1824            Face Serums    treatments     11.7K
#
#                                                img_link    price  \
# 0     https://www.sephora.com/productimages/sku/s234...   $34.00
# 1     https://www.sephora.com/productimages/sku/s217...   $34.00
# 2     https://www.sephora.com/productimages/sku/s167...   $48.00
# 3     https://www.sephora.com/productimages/sku/s231...  $125.00
# 4     https://www.sephora.com/productimages/sku/s534...   $32.00
# ...                                                 ...      ...
# 1820  https://www.sephora.com/productimages/sku/s225...   $62.00
# 1821  https://www.sephora.com/productimages/sku/s211...   $55.00
# 1822  https://www.sephora.com/productimages/sku/s226...   $82.00
# 1823  https://www.sephora.com/productimages/sku/s230...   $68.00
# 1824  https://www.sephora.com/productimages/sku/s186...   $58.00
#
#                  size                                        ingredients  \
# 0     5.07 oz/ 150 mL  [ -Watermelon Extract: Hydrates, delivers esse...
# 1                None  [ -Nourishing Fruit Salad Blend: A mix of non-...
# 2      5.1 oz/ 150 mL  [ -Japanese Camellia Oil (Tsubaki): Seals in m...
# 3       1.7 oz/ 50 mL  [ -Micro-exfoliating Minerals (Quartz, Garnet,...
# 4      4.2 oz/ 125 mL  [Aqua/Water, Cyclopentasiloxane, Isohexadecane...
# ...               ...                                                ...
# 1820    1.0 oz/ 30 mL  [ -Four Forms of Vitamin C (Natural Acerola Ch...
# 1821             None  [EradiKate® Acne Treatment:, -Sulfur 10%, Isop...
# 1822  0.7 oz/ 20.7 mL  [Water\Aqua\Eau, Dimethicone, Glycerin, Methyl...
# 1823    0.5 oz/ 15 mL  [ -10% Azelaic Acid Derivative: Water soluble ...
# 1824             1 oz  [ -Peptides: Help reduce the appearance of wri...
#
#          rating  num_reviews  \
# 0     4.5 stars         1900
# 1       4 stars         1300
# 2     4.5 stars         1700
# 3     4.5 stars         1200
# 4     4.5 stars         3700
# ...         ...          ...
# 1820  3.5 stars          210
# 1821    4 stars           50
# 1822  4.5 stars           32
# 1823    4 stars           78
# 1824    4 stars           76
#
#                                              highlights product_id
# 0     [Good for: Pores , Good for: Dullness/Uneven T...    p409800
# 1     [allure 2019 Best of Beauty Award Winner: Clea...    p409800
# 2     [Clean at Sephora, Hydrating, Best for Dry, Co...    p409800
# 3     [Clean at Sephora, Best for Dry, Combo, Normal...    p409800
# 4                                                    []    p409800
# ...                                                 ...        ...
# 1820  [Best for Dry, Combo, Normal Skin, Good for: A...    p446908
# 1821                                                 []    p446908
# 1822  [Good for: Dullness/Uneven Texture, Good for: ...    p446908
# 1823  [Best for Dry, Combo, Normal Skin, Good for: D...    p411398
# 1824                                                 []    p411398
#
# [1825 rows x 17 columns]

# %%
with open('../data/raw_data/full_reviews.json', 'r') as file:
    raw_data= json.load(file)
reviews=pd.DataFrame.from_dict(raw_data)

# %%
reviews
# Out:
#              reviewer r_productid  r_star r_eyecolor r_haircolor r_skintone  \
# 0          Becca07017     P409800       5      brown      auburn       fair
# 1     angelbeautytalk     P426340       5      green      blonde      light
# 2           Carrie314     P417113       4      brown      blonde      light
# 3         rachelwhywu     P417113       5      brown       black     medium
# 4         rachelwhywu     P417113       5      brown       black     medium
# ...               ...         ...     ...        ...         ...        ...
# 1035           Hana55     P446908       5      hazel      blonde  porcelain
# 1036            Tcd38     P411398       5      green      blonde      light
# 1037            Tcd38     P411398       5      green      blonde      light
# 1038           Wewe95     P444984       5       None        None       None
# 1039        Julia1114     P464241       5      green    brunette     medium
#
#        r_skintype r_skinconcerns  \
# 0     combination           acne
# 1            oily           acne
# 2             dry           acne
# 3     combination           acne
# 4     combination           acne
# ...           ...            ...
# 1035          dry          aging
# 1036  combination           acne
# 1037  combination           acne
# 1038         None           None
# 1039  combination        redness
#
#                                                r_review
# 0     like the cute size, easy to take with me. And ...
# 1     It’s a very nice gentle exfoliate. It’s doesn’...
# 2     I love the smell of this, it’s a very cooling ...
# 3     i have been using this since my mom tossed me ...
# 4     i have been using this since my mom tossed me ...
# ...                                                 ...
# 1035  Le sérum anti-âge Advanced Night Repair d’Esté...
# 1036          Like a drink of water for your skin! Fab!
# 1037          Like a drink of water for your skin! Fab!
# 1038  I am a big lover of this product!!! I wish I c...
# 1039  I’ve only used this product around 10ish times...
#
# [1040 rows x 9 columns]
